# %% [markdown]
# # Feature Engineering
# This notebook illustrates hybrid URL, domain, and content feature extraction.

# %%
from src.feature_engineering import build_feature_row

sample = build_feature_row('https://example.com', include_content=False)
sample
