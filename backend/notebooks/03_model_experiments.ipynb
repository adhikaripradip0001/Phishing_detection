# %% [markdown]
# # Model Experiments
# This notebook supports the supervised learning comparison for the dissertation.

# %%
import pandas as pd
from pathlib import Path

dataset_path = Path('..') / 'data' / 'processed' / 'selected_features_dataset.csv'
if dataset_path.exists():
    df = pd.read_csv(dataset_path)
    df.head()
else:
    print('Run training first to create the selected feature dataset.')
