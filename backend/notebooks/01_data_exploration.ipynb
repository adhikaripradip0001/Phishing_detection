# %% [markdown]
# # Data Exploration
# This notebook documents the raw URL datasets used for the phishing detection study.

# %%
import pandas as pd
from pathlib import Path

raw_path = Path('..') / 'data' / 'raw' / 'combined_raw.csv'
df = pd.read_csv(raw_path)
df.head()
